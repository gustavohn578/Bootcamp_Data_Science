# %%
import pandas as pd
dados = pd.read_csv("/content/A213524189_28_143_208.csv", encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12, 
                    thousands=".", decimal=",", engine='python')
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2021/Mar         Total
# 0          11 Rondônia        -  ...   4732441.04  9.964113e+08
# 1              12 Acre        -  ...   1137341.65  4.500485e+08
# 2          13 Amazonas        -  ...   6799060.80  1.917248e+09
# 3           14 Roraima        -  ...   2381844.31  3.288770e+08
# 4              15 Pará        -  ...  13069564.31  4.705309e+09
#
# [5 rows x 287 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2021/Mar         Total
# 22   43 Rio Grande do Sul        -  ...  37798832.80  1.276439e+10
# 23  50 Mato Grosso do Sul        -  ...   4035989.77  2.324525e+09
# 24         51 Mato Grosso        -  ...   8835890.09  2.180120e+09
# 25               52 Goiás        -  ...  24867001.02  4.973572e+09
# 26    53 Distrito Federal        -  ...  14731938.43  2.592423e+09
#
# [5 rows x 287 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 287 entries, Unidade da Federação to Total
# dtypes: float64(165), object(122)
# memory usage: 60.7+ KB

# %%
pd.options.display.float_format = "{:.2f}".format
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
dados.at[22,'2008/Jan']
# Out:
# 51064610.03

# %%
dados['2008/Ago'].mean()
# Out:
# 26641365.101481482

# %%
dados.plot(x="Unidade da Federação",y="2008/Ago", kind='bar',figsize=(9,7))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação",y="2008/Ago", kind='bar',figsize=(9,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()

# %% [markdown]
# **Desafio: escolher um título mais descritivo, que passe a mensagem adequada.**

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação",y="2008/Ago", kind='bar',figsize=(9,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) 

plt.ylabel("Valor total [R$]")
plt.title("Procedimentos hospitalares do SUS - Valor por unidade da federação")
plt.show()

# %% [markdown]
# **Desafio: faça a mesma análise para um mês mais recente.**

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação",y="2020/Ago", kind='bar',figsize=(9,7), color='red')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) 

plt.ylabel("Valor total [R$]")
plt.title("Procedimentos hospitalares do SUS - Valor por unidade da federação")
plt.show()

# %%
dados[["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %% [markdown]
# Problema: muitas colunas com poucas informacoes. Como trazer somentes as colunas com todas as informações? Varias solucoes possiveis. Ex.:
# Media (mean) traz somente resultados para colunas com todos os valores presentes.
# Outras estratégias: Fill NA, Drop NA, preencher com media etc

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %% [markdown]
# mean().index informa colunas com todos os valores presentes

# %%
usaveis = dados[colunas_usaveis]
usaveis
# Out:
#       Unidade da Federação   2007/Ago  ...     2021/Mar          Total
# 0              11 Rondônia    4209.37  ...   4732441.04   996411254.68
# 1                  12 Acre   10470.07  ...   1137341.65   450048530.47
# 2              13 Amazonas   35752.72  ...   6799060.80  1917247936.05
# 3               14 Roraima    4785.91  ...   2381844.31   328876965.09
# 4                  15 Pará  181159.29  ...  13069564.31  4705309002.29
# 5                 16 Amapá   33672.74  ...    989155.40   309860092.59
# 6             17 Tocantins    4113.76  ...    928756.84  1020028272.64
# 7              21 Maranhão  385330.18  ...  17294509.11  3871069498.04
# 8                 22 Piauí  220788.25  ...   9542151.53  2280888802.74
# 9                 23 Ceará  357904.65  ...  17173151.55  6591836650.18
# 10  24 Rio Grande do Norte  134605.36  ...   8733455.36  2660122027.15
# 11              25 Paraíba   97352.78  ...  12517894.05  2614919044.63
# ...

# %% [markdown]
# Problema: index deveria ser a Unidade da Federação
# Solução: set_index

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996411254.68
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450048530.47
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917247936.05
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876965.09
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705309002.29
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309860092.59
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1020028272.64
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871069498.04
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280888802.74
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591836650.18
# ...

# %%
usaveis['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %% [markdown]
# **Dados de uma linha:**

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis.T #transposto
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2007/Ago                  4209.37  ...            191951.47
# 2007/Set                 16397.03  ...            769966.25
# 2007/Out                133645.19  ...           2165619.56
# 2007/Nov                346912.84  ...           3813256.48
# 2007/Dez                711758.31  ...           7121965.42
# ...                           ...  ...                  ...
# 2020/Dez               9003402.23  ...          22552034.04
# 2021/Jan               8414690.60  ...          22573869.50
# 2021/Fev               6039419.59  ...          19004029.87
# 2021/Mar               4732441.04  ...          14731938.43
# Total                996411254.68  ...        2592422853.56
#
# [165 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %%
usaveis = usaveis.drop("Total", axis=1)

# %%
usaveis.tail()
# Out:
#                         2007/Ago   2007/Set  ...    2021/Fev    2021/Mar
# Unidade da Federação                         ...
# 43 Rio Grande do Sul  1049252.33 3182913.14  ... 84404640.00 37798832.80
# 50 Mato Grosso do Sul  199556.12  573675.41  ... 11428462.42  4035989.77
# 51 Mato Grosso          63562.50  232444.62  ... 13207979.82  8835890.09
# 52 Goiás               179395.82  418053.58  ... 32253788.65 24867001.02
# 53 Distrito Federal    191951.47  769966.25  ... 19004029.87 14731938.43
#
# [5 rows x 164 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %% [markdown]
# **Desafio: reposicionas a legenda separada do gráfico**

# %%
import matplotlib.pyplot as plt

usaveis.T.plot(figsize=(10,6))

plt.legend(loc="upper right", ncol=2, bbox_to_anchor=(1.6, 1))

# %% [markdown]
# **Desafio: mudar a paleta de cores com o matplotlib**

# %%
usaveis.T.columns[0:5] #nome das colunas - slice do primeio ao quinto elemento [inclui inicio, exclui final]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index[:5] #nome das colunas - slice do primeio ao quinto elemento (omitindo o 0)
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[:5]
# Out:
#                       2007/Ago  2007/Set  ...    2021/Fev    2021/Mar
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  6039419.59  4732441.04
# 12 Acre               10470.07  14001.71  ...  2272733.90  1137341.65
# 13 Amazonas           35752.72  45570.64  ... 13679358.06  6799060.80
# 14 Roraima             4785.91  11858.63  ...  3044798.77  2381844.31
# 15 Pará              181159.29 433414.74  ... 23343222.94 13069564.31
#
# [5 rows x 164 columns]

# %%
usaveis[0:5].T.plot(figsize=(10,6))#slice do primeiro ao quinto estado

# %%
ax = usaveis[:7].T.plot(figsize=(10,6))#estados do norte

# %%
usaveis.sample(n=7) #amostra aleatórias / resultados diferentes a cada execução (pseudoaleatório)
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 25 Paraíba             97352.78  368130.43  ...  16996494.03  12517894.05
# 23 Ceará              357904.65  572356.18  ...  30186951.00  17173151.55
# 42 Santa Catarina     693955.05 1092964.12  ...  47429335.91  19375822.56
# 26 Pernambuco         400640.85 1088340.42  ...  62259409.32  39472738.81
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  84404640.00  37798832.80
# 51 Mato Grosso         63562.50  232444.62  ...  13207979.82   8835890.09
# 35 São Paulo         1665349.90 4434168.64  ... 268193064.06 177408317.71
#
# [7 rows x 164 columns]

# %%
import numpy as np #biblioteca de funcoes matematicas
np.random.seed(687942)
usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set  ...     2021/Fev    2021/Mar
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  25669612.63 15606368.11
# 31 Minas Gerais        971394.37 2861781.50  ... 119877417.15 79780838.00
# 24 Rio Grande do Norte 134605.36  272088.08  ...  18186942.80  8733455.36
# 17 Tocantins             4113.76   76633.06  ...    416534.32   928756.84
# 53 Distrito Federal    191951.47  769966.25  ...  19004029.87 14731938.43
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  11428462.42  4035989.77
# 16 Amapá                33672.74  104822.98  ...   1534733.18   989155.40
#
# [7 rows x 164 columns]

# %%
usaveis.sample(n=7)
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 42 Santa Catarina     693955.05 1092964.12  ...  47429335.91  19375822.56
# 33 Rio de Janeiro     469469.34  921646.57  ...  60873103.08  49149884.48
# 31 Minas Gerais       971394.37 2861781.50  ... 119877417.15  79780838.00
# 35 São Paulo         1665349.90 4434168.64  ... 268193064.06 177408317.71
# 21 Maranhão           385330.18 1018352.93  ...  23260245.95  17294509.11
# 52 Goiás              179395.82  418053.58  ...  32253788.65  24867001.02
# 32 Espírito Santo      57408.11  284224.80  ...  25669612.63  15606368.11
#
# [7 rows x 164 columns]

# %% [markdown]
# **Desafio: adicionar uma coluna mostrando a região de cada estado.**
#
# ---

# %%
usaveis["Total"] = usaveis.sum(axis=1)#reinseri total
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...    2021/Mar         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  4732441.04  996410650.35
# 12 Acre               10470.07  14001.71  ...  1137341.65  450047246.65
# 13 Amazonas           35752.72  45570.64  ...  6799060.80 1917245104.64
# 14 Roraima             4785.91  11858.63  ...  2381844.31  328876551.40
# 15 Pará              181159.29 433414.74  ... 13069564.31 4705290466.69
#
# [5 rows x 165 columns]

# %%
ordenado_por_total = usaveis.sort_values("Total",ascending=False)
ordenado_por_total = ordenado_por_total.drop("Total",axis=1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 268193064.06 177408317.71
# 31 Minas Gerais       971394.37 2861781.50  ... 119877417.15  79780838.00
# 41 Paraná             554800.22 1431708.01  ...  83130175.37  43480729.07
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  84404640.00  37798832.80
# 33 Rio de Janeiro     469469.34  921646.57  ...  60873103.08  49149884.48
#
# [5 rows x 164 columns]

# %% [markdown]
# **Desafio: Deixar o gráfico mais bonito e a mensagem mais clara.**

# %%
ordenado_por_total.head().T.plot(figsize=(10,6))

# %% [markdown]
# **Desafio: adicione o seu estado aos 5 estados existentes no plot.**
# **Plus: Eliminar o período no inicio da serie para melhorar a escala da análise**.

# %% [markdown]
# **Desafio: pesquisar os surtos dengue no Brasil e verificar se refletem nos gastos.**

# %% [markdown]
# **Desafio: plotar só os estados do Sudeste e verificar se foram afetados de forma similar no pico de 2012/2013**
