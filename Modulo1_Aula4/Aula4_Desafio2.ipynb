# %% [markdown]
# **Desafio 02: Reflita sobre os problemas na manipulação de dados e discuta esse assunto no Discord.**

# %% [markdown]
# **Um assunto polêmico é o uso de pesquisas eleitorias para influenciar os resultados das eleições. No exemplo abaixo temos um caso grotesco de manipulação de um gráfico dos resultados de uma pesquisa para distorcer as informações. Os pontos que saltam a vista é escala totalmente errada e o tamanho desproporcional das barras.**

# %% [markdown]
# https://especiais.gazetadopovo.com.br/eleicoes/2018/pesquisas-eleitorais/ibope/pagina-oficial-psdb-sp-divulga-grafico-distorcido-de-pesquisa-com-doria/

# %% [markdown]
# ![graficofake2.png](data:image/png;base64,...)
